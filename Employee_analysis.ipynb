# %% [markdown]
# ##**EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# #Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Load the data

# %% [markdown]
# *  Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.
# *  print the head of the dataframe.

# %%
data=pd.read_csv("company_employee_details.csv")

# %% [markdown]
# #First Five Rows of the Data

# %%
data.head()
# Out:
#    Unnamed: 0   company     department  employee_id  age  age_when_joined  \
# 0           0   Glasses        BigData           16   41               38
# 1           1   Glasses             AI           56   44               42
# 2           2  Cheerper        Support           59   41               40
# 3           3   Glasses         Design           40   39               32
# 4           4   Glasses  Search Engine           47   30               22
#
#    years_in_the_company         salary  annual_bonus  prior_years_experience  \
# 0                     3   68074.971354  17664.104103                       3
# 1                     2   49092.147458  21551.141079                       2
# 2                     1   40000.000000  23698.878851                       2
# 3                     7  108192.465506  21570.929657                       1
# 4                     9   71291.191132  21565.505715                       2
#
#    full_time  part_time  contractor
# ...

# %% [markdown]
# #Last Five Rows of the Data

# %%
data.tail()
# Out:
#       Unnamed: 0   company     department  employee_id  age  age_when_joined  \
# 4995        4995  Cheerper  Search Engine           37   42               35
# 4996        4996   Glasses             AI            1   36               25
# 4997        4997   Glasses  Search Engine           20   35               30
# 4998        4998      Pear          Sales            9   49               48
# 4999        4999   Glasses             AI           36   43               38
#
#       years_in_the_company         salary  annual_bonus  \
# 4995                     7   76541.841502  17366.896122
# 4996                     9  113651.485089  20888.144794
# 4997                     5   77560.047560  24792.910000
# 4998                     1  153000.000000  11700.850325
# 4999                     5   91443.504951  13529.040663
#
#       prior_years_experience  full_time  part_time  contractor
# 4995                       2   0.269842   0.691977    0.038156
# ...

# %% [markdown]
# #Columns Names of the Data

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'company', 'department', 'employee_id', 'age',
#        'age_when_joined', 'years_in_the_company', 'salary', 'annual_bonus',
#        'prior_years_experience', 'full_time', 'part_time', 'contractor'],
#       dtype='object')

# %% [markdown]
# #Shape of Data

# %%
data.shape
# Out:
# (5000, 13)

# %%
data.describe()
# Out:
#         Unnamed: 0  employee_id          age  age_when_joined  \
# count  5000.000000  5000.000000  5000.000000      5000.000000
# mean   2499.500000    30.608400    38.131800        33.504600
# std    1443.520003    22.867375     6.040143         7.767165
# min       0.000000     1.000000    30.000000        22.000000
# 25%    1249.750000    10.000000    33.000000        27.000000
# 50%    2499.500000    29.000000    38.000000        33.000000
# 75%    3749.250000    47.000000    43.000000        39.000000
# max    4999.000000    80.000000    49.000000        48.000000
#
#        years_in_the_company         salary  annual_bonus  \
# count           5000.000000    5000.000000   5000.000000
# mean               4.662000   87169.773408  18602.668196
# std                2.547755   28387.516846   4412.142023
# min                1.000000   40000.000000   9000.000000
# 25%                3.000000   66068.490326  15412.930670
# 50%                5.000000   86633.575487  18786.655969
# ...

# %% [markdown]
# #Information of our Data like Column Names,Data types ,Memory usage etc

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5000 non-null   int64
#  1   company                 5000 non-null   object
#  2   department              5000 non-null   object
#  3   employee_id             5000 non-null   int64
#  4   age                     5000 non-null   int64
#  5   age_when_joined         5000 non-null   int64
#  6   years_in_the_company    5000 non-null   int64
#  7   salary                  5000 non-null   float64
#  8   annual_bonus            5000 non-null   float64
#  9   prior_years_experience  5000 non-null   int64
#  10  full_time               5000 non-null   float64
#  11  part_time               5000 non-null   float64
#  12  contractor              5000 non-null   float64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 507.9+ KB

# %% [markdown]
# #Checking the types of data

# %%
data.dtypes
# Out:
# Unnamed: 0                  int64
# company                    object
# department                 object
# employee_id                 int64
# age                         int64
# age_when_joined             int64
# years_in_the_company        int64
# salary                    float64
# annual_bonus              float64
# prior_years_experience      int64
# full_time                 float64
# part_time                 float64
# contractor                float64
# dtype: object

# %% [markdown]
# #Detect missing values in data

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# company                   0
# department                0
# employee_id               0
# age                       0
# age_when_joined           0
# years_in_the_company      0
# salary                    0
# annual_bonus              0
# prior_years_experience    0
# full_time                 0
# part_time                 0
# contractor                0
# dtype: int64

# %% [markdown]
# #duplicated() method identifies duplicated rows in a DataFrame

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Counts the values in the "company" column

# %%
data['company'].value_counts()
# Out:
# Glasses     2369
# Cheerper    1440
# Pear        1191
# Name: company, dtype: int64

# %% [markdown]
# #Counts the values in the "department" column

# %%
data['department'].value_counts()
# Out:
# AI               1128
# Search Engine    1071
# BigData           797
# Design            720
# Sales             653
# Support           631
# Name: department, dtype: int64

# %% [markdown]
# #Counts the values in the "rior_years_experience" column

# %%
data['prior_years_experience'].value_counts()
# Out:
# 2    1341
# 1    1289
# 3    1278
# 4     777
# 5     315
# Name: prior_years_experience, dtype: int64

# %% [markdown]
# #This graph tell us about Various company in which employee works
# <ul font_size = 20px>
#
# * 47.4 percent employee work in Glasses Company.
# * 28.8 percent employee work in Cheerper Company.
# * 23.8 percent employee work in Pear Company.
# </ul>

# %%
plt.figure(figsize=(20,8))
data['company'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('Company')
plt.xlabel('graph')
plt.title('Various Company in which Employee works')
# Out:
# Text(0.5, 1.0, 'Various Company in which Employee works')

# %% [markdown]
# #The graph tell us about various Department in which Employee works.
#
# * 21.4% Employees works in Search Engine Department.
# * 22.6% Employees works in AI Department.
# * 15.9% Employees works in Bigdata Department.
# * 12.6% Employees works in Support Department.
# * 14.4% Employees works in Design Department.
# * 13.1% Employees works in Sales department.

# %%
plt.figure(figsize=(20,8))
data['department'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('Department')
plt.xlabel('graph')
plt.title('Various Department in which Employee works')
# Out:
# Text(0.5, 1.0, 'Various Department in which Employee works')

# %% [markdown]
# #The graph will tell us years of prior experience of employees

# %%
plt.figure(figsize=(20,8))
data['prior_years_experience'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('Prior year Experience')
plt.xlabel('graph')
plt.title('Years of Prior Experience')
# Out:
# Text(0.5, 1.0, 'Years of Prior Experience')

# %% [markdown]
# #Hestogrsm of Age when employees joined.

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age')
plt.subplot(1,2,2)
plt.hist(df['age_when_joined'])
plt.xlabel('Age when joined')
plt.ylabel('Count')
plt.title('Histogram of Age when joined')
# Out:
# Text(0.5, 1.0, 'Histogram of Age when joined')

# %% [markdown]
# #Hestogrsm of Age when employees joined.

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(data['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age')
plt.subplot(1,2,2)
plt.hist(data['age_when_joined'])
plt.xlabel('Age when joined')
plt.ylabel('Count')
plt.title('Histogram of Age when joined')
# Out:
# Text(0.5, 1.0, 'Histogram of Age when joined')

# %% [markdown]
# #Histogram of employees are contractor or not.

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(data['years_in_the_company'])
plt.xlabel('Year worked')
plt.ylabel('Count')
plt.title('Histogram of Year worked')
plt.subplot(1,2,2)
plt.hist(data['contractor'])
plt.xlabel('Contractor')
plt.ylabel('Count')
plt.title('Histogram of contractor or not')
# Out:
# Text(0.5, 1.0, 'Histogram of contractor or not')

# %% [markdown]
# #Histogram of annual bonus received.

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(data['salary'])
plt.xlabel('Salary')
plt.ylabel('Count')
plt.title('Histogram of Salary')
plt.subplot(1,2,2)
plt.hist(data['annual_bonus'])
plt.xlabel('Annual Bonus')
plt.ylabel('Count')
plt.title('Histogram of Annual Bonus received')
# Out:
# Text(0.5, 1.0, 'Histogram of Annual Bonus received')

# %% [markdown]
# #Histogram of Part Time Employee count.

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(df['full_time'])
plt.xlabel('Full Time')
plt.ylabel('Count')
plt.title('Histogram of Full Time Employee')
plt.subplot(1,2,2)
plt.hist(df['part_time'])
plt.xlabel('Part Time')
plt.ylabel('Count')
plt.title('Histogram of Part Time Employee')
# Out:
# Text(0.5, 1.0, 'Histogram of Part Time Employee')
